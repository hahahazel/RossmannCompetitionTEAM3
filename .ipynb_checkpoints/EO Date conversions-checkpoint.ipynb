# %%
import pandas as pd
import numpy as np

import pandas_profiling as pp
from pandas_profiling import ProfileReport


# reading two csv files
data1 = pd.read_csv('data/train.csv', dtype={'Store':'string'})
data2 = pd.read_csv('data/store.csv', dtype={'Store':'string', 'StoreType':'string', 'Assortment':'string'})

# using merge function by setting how='inner'
total = pd.merge(data1, data2,
                   on='Store',
                   how='inner')
print(data1.dtypes)

print(data2.dtypes)
# Out:
# /home/eero/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Date              object
# Store             string
# DayOfWeek        float64
# Sales            float64
# Customers        float64
# Open             float64
# Promo            float64
# StateHoliday      object
# SchoolHoliday    float64
# dtype: object
# Store                         string
# StoreType                     string
# Assortment                    string
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                 object
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637774 entries, 0 to 637773
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           637774 non-null  object
#  1   Store          618473 non-null  string
#  2   DayOfWeek      618757 non-null  float64
#  3   Sales          618747 non-null  float64
#  4   Customers      618683 non-null  float64
#  5   Open           618588 non-null  float64
#  6   Promo          618580 non-null  float64
#  7   StateHoliday   618520 non-null  object
#  8   SchoolHoliday  618437 non-null  float64
# dtypes: float64(6), object(2), string(1)
# memory usage: 43.8+ MB

# %%
from datetime import datetime 
from datetime import date 

## Create a new column that is a real date.
## For a time series we need real dates.
total['sales_date'] = pd.to_datetime(total['Date'])
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 618473 entries, 0 to 618472
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date                       618473 non-null  object
#  1   Store                      618473 non-null  string
#  2   DayOfWeek                  600036 non-null  float64
#  3   Sales                      600028 non-null  float64
#  4   Customers                  599957 non-null  float64
#  5   Open                       599832 non-null  float64
#  6   Promo                      599791 non-null  float64
#  7   StateHoliday               599873 non-null  object
#  8   SchoolHoliday              599686 non-null  float64
#  9   StoreType                  618473 non-null  string
#  10  Assortment                 618473 non-null  string
#  11  CompetitionDistance        616838 non-null  float64
#  12  CompetitionOpenSinceMonth  422043 non-null  float64
#  13  CompetitionOpenSinceYear   422043 non-null  float64
#  14  Promo2                     618473 non-null  int64
#  15  Promo2SinceWeek            314828 non-null  float64
#  16  Promo2SinceYear            314828 non-null  float64
#  17  PromoInterval              314828 non-null  object
#  18  sales_date                 618473 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(1), object(3), string(3)
# memory usage: 94.4+ MB

# %%
#Create a date out of the Promo2 variables so that we can create a time-series variable for Promo2
    
total['temp_date'] = total['Promo2SinceYear'] * 1000 + total['Promo2SinceWeek']  * 10 + 0
total['promo2_start_date'] = pd.to_datetime(total['temp_date'], format='%Y%W%w')
total = total.drop(columns=['temp_date'])
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 618473 entries, 0 to 618472
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date                       618473 non-null  object
#  1   Store                      618473 non-null  string
#  2   DayOfWeek                  600036 non-null  float64
#  3   Sales                      600028 non-null  float64
#  4   Customers                  599957 non-null  float64
#  5   Open                       599832 non-null  float64
#  6   Promo                      599791 non-null  float64
#  7   StateHoliday               599873 non-null  object
#  8   SchoolHoliday              599686 non-null  float64
#  9   StoreType                  618473 non-null  string
#  10  Assortment                 618473 non-null  string
#  11  CompetitionDistance        616838 non-null  float64
#  12  CompetitionOpenSinceMonth  422043 non-null  float64
#  13  CompetitionOpenSinceYear   422043 non-null  float64
#  14  Promo2                     618473 non-null  int64
#  15  Promo2SinceWeek            314828 non-null  float64
#  16  Promo2SinceYear            314828 non-null  float64
#  17  PromoInterval              314828 non-null  object
#  18  sales_date                 618473 non-null  datetime64[ns]
#  19  promo2_start_date          314828 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(11), int64(1), object(3), string(3)
# memory usage: 99.1+ MB

# %%
       
## Create an array to Group the data by group. and make dummy Store by Store
for Store, grouped in total.groupby('Store'):
   if [total['Promo2'] == 0]:
      total['Promo2_yes'] = 0
   elif  [total['Promo2_start_date'].isnull()]:
      total['Promo2_yes'] = 0
   elif [(total['sales_date'] >= total['Promo2_start_date'])]:
      total['Promo2_yes'] = 1
   else:
      total['Promo2_yes'] = 0

total.head()
# Out:
#          Date Store  DayOfWeek   Sales  Customers  Open  Promo StateHoliday  \
# 0  2013-01-01  1115        2.0     0.0        0.0   0.0    0.0            a
# 1  2013-01-02  1115        3.0  3697.0      305.0   1.0    0.0            0
# 2  2013-01-03  1115        4.0  4297.0      300.0   1.0    0.0            0
# 3  2013-01-04  1115        5.0  4540.0      326.0   1.0    0.0            0
# 4  2013-01-05  1115        6.0  4771.0      339.0   1.0    0.0            0
#
#    SchoolHoliday StoreType  ... CompetitionDistance  \
# 0            1.0         d  ...              5350.0
# 1            1.0         d  ...              5350.0
# 2            1.0         d  ...              5350.0
# 3            1.0         d  ...              5350.0
# 4            1.0         d  ...              5350.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        NaN                       NaN       1
# 1                        NaN                       NaN       1
# 2                        NaN                       NaN       1
# 3                        NaN                       NaN       1
# 4                        NaN                       NaN       1
#
#    Promo2SinceWeek  Promo2SinceYear     PromoInterval sales_date  \
# 0             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-01
# 1             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-02
# 2             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-03
# 3             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-04
# 4             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-05
#
#   promo2_start_date Promo2_yes
# 0        2012-06-03          0
# 1        2012-06-03          0
# 2        2012-06-03          0
# 3        2012-06-03          0
# 4        2012-06-03          0
#
# [5 rows x 21 columns]

# %%
print(total.groupby('Promo2').mean(total['Promo2']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19262/1711265280.py in <module>
# ----> 1 print(total.groupby('Promo2').mean(total['Promo2']))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1682         numeric_only = self._resolve_numeric_only(numeric_only)
#    1683
# -> 1684         result = self._cython_agg_general(
#    1685             "mean",
#    1686             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1061         data: Manager2D = self._get_data_to_aggregate()
#    1062
# -> 1063         if numeric_only:
#    1064             data = data.get_numeric_data(copy=False)
#    1065
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
def create_a_timeseries_dummy_from_weeks(df, var_week, var_year, date_new, var_dummy):
    #Create a date out of the Promo2 variables so that we can create a time-series variable for Promo2
    df['temp_date'] = df[var_year] * 1000 + df[var_week]  * 10 + 0
    df[date_new] = pd.to_datetime(df['temp_date'], format='%Y%W%w')
    ## Create an array to Group the data by group. and make dummy Store by Store
    for Store, grouped in df.groupby('Store'):
      if [df['sales_date'] >= df[date_new]]:
        df[var_dummy] = 1
      else:
        df[var_dummy] = 0
    df = df.drop(columns=['temp_date'])
    df.head()

    
def create_a_timeseries_dummy_from_months(df, var_month, var_year, date_new, var_dummy):
    #Create a date out of the Competition variables so that we can create a time-series variable for Competitioin
    df['temp_date'] = df[var_year] * 1000 + df[var_month]  * 10 + 0
    ## Create an array to Group the data by group. and make dummy Store by Store
    df[date_new] = pd.to_datetime(df['temp_date'], format='%Y%m%w')
    for Store, grouped in df.groupby('Store'):
      if [df['sales_date'] >= df[date_new]]:
        df[var_dummy] = 1
      else:
        df[var_dummy] = 0
    df = df.drop(columns=['temp_date'])    
    df.head()

# %%
total.head()
# Out:
#          Date Store  DayOfWeek   Sales  Customers  Open  Promo StateHoliday  \
# 0  2013-01-01  1115        2.0     0.0        0.0   0.0    0.0            a
# 1  2013-01-02  1115        3.0  3697.0      305.0   1.0    0.0            0
# 2  2013-01-03  1115        4.0  4297.0      300.0   1.0    0.0            0
# 3  2013-01-04  1115        5.0  4540.0      326.0   1.0    0.0            0
# 4  2013-01-05  1115        6.0  4771.0      339.0   1.0    0.0            0
#
#    SchoolHoliday StoreType  ... CompetitionDistance  \
# 0            1.0         d  ...              5350.0
# 1            1.0         d  ...              5350.0
# 2            1.0         d  ...              5350.0
# 3            1.0         d  ...              5350.0
# 4            1.0         d  ...              5350.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        NaN                       NaN       1
# 1                        NaN                       NaN       1
# 2                        NaN                       NaN       1
# 3                        NaN                       NaN       1
# 4                        NaN                       NaN       1
#
#    Promo2SinceWeek  Promo2SinceYear     PromoInterval sales_date  \
# 0             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-01
# 1             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-02
# 2             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-03
# 3             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-04
# 4             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-05
#
#   promo2_start_date Promo2_yes
# 0        2012-06-03          0
# 1        2012-06-03          0
# 2        2012-06-03          0
# 3        2012-06-03          0
# 4        2012-06-03          0
#
# [5 rows x 21 columns]

# %%
create_a_timeseries_dummy_from_weeks(df=total,
                                     var_week='Promo2SinceWeek'  ,
                                     var_year='Promo2SinceYear'  ,
                          date_new='Promo2_start_date'          ,
                          var_dummy='Promo2_yes'
                                    )

# %%
create_a_timeseries_dummy_from_months(df=total   ,
                          var_month='CompetitionOpenSinceMonth'  ,
                          var_year='CompetitionOpenSinceYear'   ,
                          date_new='Competition_start_date'    ,
                          var_dummy='Competition_yes'
                                    )

# %%
total.head()
# Out:
#          Date Store  DayOfWeek   Sales  Open  Promo StateHoliday  \
# 0  2013-01-01  1115        2.0     0.0   0.0    0.0            a
# 1  2013-01-02  1115        3.0  3697.0   1.0    0.0            0
# 2  2013-01-03  1115        4.0  4297.0   1.0    0.0            0
# 3  2013-01-04  1115        5.0  4540.0   1.0    0.0            0
# 4  2013-01-05  1115        6.0  4771.0   1.0    0.0            0
#
#    SchoolHoliday StoreType Assortment  ...  CompetitionOpenSinceYear  Promo2  \
# 0            1.0         d          c  ...                       NaN       1
# 1            1.0         d          c  ...                       NaN       1
# 2            1.0         d          c  ...                       NaN       1
# 3            1.0         d          c  ...                       NaN       1
# 4            1.0         d          c  ...                       NaN       1
#
#    Promo2SinceWeek  Promo2SinceYear     PromoInterval  sales_date Promo2_date  \
# 0             22.0           2012.0  Mar,Jun,Sept,Dec  2013-01-01  2012-06-03
# 1             22.0           2012.0  Mar,Jun,Sept,Dec  2013-01-02  2012-06-03
# 2             22.0           2012.0  Mar,Jun,Sept,Dec  2013-01-03  2012-06-03
# 3             22.0           2012.0  Mar,Jun,Sept,Dec  2013-01-04  2012-06-03
# 4             22.0           2012.0  Mar,Jun,Sept,Dec  2013-01-05  2012-06-03
#
#    temp_date   date_new  Promo2_start_date
# 0  2012220.0 2012-06-03         2012-06-03
# 1  2012220.0 2012-06-03         2012-06-03
# 2  2012220.0 2012-06-03         2012-06-03
# 3  2012220.0 2012-06-03         2012-06-03
# 4  2012220.0 2012-06-03         2012-06-03
#
# [5 rows x 22 columns]

# %%
create_a_timeseries_dummy_from_months(df=total                  ,
                          var_month='CompetitionOpenSinceYear'  ,
                          var_year='CompetitionOpenSinceMonth'  ,
                          date_new='Competition_start_date',
                          var_dummy='Competition_yes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14083/1826195018.py in <module>
# ----> 1 create_a_timeseries_dummy_from_months(df=total                  ,
#       2                           var_month='CompetitionOpenSinceYear'  ,
#       3                           var_year='CompetitionOpenSinceMonth'  ,
#       4                           date_new='Competition_start_date',
#       5                           var_dummy='Competition_yes')
#
# /tmp/ipykernel_14083/3153499287.py in create_a_timeseries_dummy_from_months(df, var_month, var_year, date_new, var_dummy)
#      21     ## Create an array to Group the data by group. and make dummy Store by Store
#      22     for Store, grouped in df.groupby('Store'):
# ---> 23       if temp_date.isnull():
#      24         df[var_dummy] = 0
#      25       elif df['sales_date'] >= df[date_new]:
#
# NameError: name 'temp_date' is not defined

# %%
  ## Create an array to Group the data by group. and make dummy Store by Store
    for Store, grouped in df.groupby('Store'):
      if temp_date.isnull():
        df.var_dummy = 0
      elif df.sales_date >= df.date_new:
        df.var_dummy = 1
      else:
        df.var_dummy = 0

# %%
# Out:
#          Date Store  DayOfWeek   Sales  Open  Promo StateHoliday  \
# 0  2013-01-01  1115        2.0     0.0   0.0    0.0            a
# 1  2013-01-02  1115        3.0  3697.0   1.0    0.0            0
# 2  2013-01-03  1115        4.0  4297.0   1.0    0.0            0
# 3  2013-01-04  1115        5.0  4540.0   1.0    0.0            0
# 4  2013-01-05  1115        6.0  4771.0   1.0    0.0            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0            1.0         d          c               5350.0
# 1            1.0         d          c               5350.0
# 2            1.0         d          c               5350.0
# 3            1.0         d          c               5350.0
# 4            1.0         d          c               5350.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        NaN                       NaN       1
# 1                        NaN                       NaN       1
# 2                        NaN                       NaN       1
# 3                        NaN                       NaN       1
# 4                        NaN                       NaN       1
#
#    Promo2SinceWeek  Promo2SinceYear     PromoInterval sales_date Promo2_date
# 0             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-01  2012-06-03
# 1             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-02  2012-06-03
# 2             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-03  2012-06-03
# 3             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-04  2012-06-03
# 4             22.0           2012.0  Mar,Jun,Sept,Dec 2013-01-05  2012-06-03

# %%
total.Promo2.value_counts()
total.Promo2_date.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14083/2720208020.py in <module>
#       1 total.Promo2.value_counts()
# ----> 2 total.Promo2_date.info
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Promo2_date'

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 618473 entries, 0 to 618472
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date                       618473 non-null  object
#  1   Store                      618473 non-null  string
#  2   DayOfWeek                  600036 non-null  float64
#  3   Sales                      600028 non-null  float64
#  4   Open                       599832 non-null  float64
#  5   Promo                      599791 non-null  float64
#  6   StateHoliday               599873 non-null  object
#  7   SchoolHoliday              599686 non-null  float64
#  8   StoreType                  618473 non-null  string
#  9   Assortment                 618473 non-null  string
#  10  CompetitionDistance        616838 non-null  float64
#  11  CompetitionOpenSinceMonth  422043 non-null  float64
#  12  CompetitionOpenSinceYear   422043 non-null  float64
#  13  Promo2                     618473 non-null  int64
#  14  Promo2SinceWeek            314828 non-null  float64
#  15  Promo2SinceYear            314828 non-null  float64
#  16  PromoInterval              314828 non-null  object
#  17  sales_date                 618473 non-null  datetime64[ns]
#  18  Promo2_date                314828 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(10), int64(1), object(3), string(3)
# memory usage: 94.4+ MB

# %%
## Create an array to Group the data by group.
for Store, grouped in total.groupby('Store'):
  if Promo2_date.isnull():
    total.Promo = 0
  elif total.sales_date >= total.Promo2_date:
    total.Promo2 = 1
  else:
    total.Promo = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14083/486599066.py in <module>
#       1 ## Create an array to Group the data by group.
#       2 for Store, grouped in total.groupby('Store'):
# ----> 3   if Promo2_date.isnull():
#       4     total.Promo = 0
#       5   elif total.sales_date >= total.Promo2_date:
#
# NameError: name 'Promo2_date' is not defined

# %%
report = ProfileReport(data1, infer_dtypes=True) 
report.to_html.write_html('prof_report.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8808/3675275321.py in <module>
#       1 report = ProfileReport(data1, infer_dtypes=True)
# ----> 2 report.to_html.write_html('prof_report.html')
#
# AttributeError: 'function' object has no attribute 'write_html'

# %%
data1["date"].apply(lambda x: x if isinstance(x,datetime.datetime) else np.nan).fillna(method = "ffill")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8808/781978489.py in <module>
# ----> 1 data1["date"].apply(lambda x: x if isinstance(x,datetime.datetime) else np.nan).fillna(method = "ffill")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'date'
